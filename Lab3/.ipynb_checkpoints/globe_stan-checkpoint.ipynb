# %% [markdown]
# ## Globe tossing experiment

# %%
import sys
#sys.path.append('../')
import pystan
import stan_utility

import arviz as az
import numpy as np
import scipy.stats as stats
print(sys.path)
# Out:
# ['D:\\materiały\\CPS-semestr1\\Data Analytics\\Repo_do_wrzucania_zadan\\Data_Analytics\\Lab3', 'C:\\Users\\Sebastian\\Anaconda3\\python37.zip', 'C:\\Users\\Sebastian\\Anaconda3\\DLLs', 'C:\\Users\\Sebastian\\Anaconda3\\lib', 'C:\\Users\\Sebastian\\Anaconda3', '', 'C:\\Users\\Sebastian\\Anaconda3\\lib\\site-packages', 'C:\\Users\\Sebastian\\Anaconda3\\lib\\site-packages\\win32', 'C:\\Users\\Sebastian\\Anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\Users\\Sebastian\\Anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\Users\\Sebastian\\Anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\Sebastian\\.ipython']

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

light="#FFFCDC"
light_highlight="#FEF590"
mid="#FDED2A"
mid_highlight="#f0dc05"
dark="#EECA02"
dark_highlight="#BB9700"
green="#00FF00"
light_grey="#DDDDDD"

plt.style.context('seaborn-white')
mpl.rcParams['figure.dpi']= 200

# %% [markdown]
# ## Non-informative uniform prior

# %% [markdown]
# ### Prior predictive distribution
# We can use stan to simulate possible outputs and parameteres based only on prior information.

# %%
with open('globe_prior.stan', 'r') as file:
    print(file.read())
# Out:
# data {
#   int N;
# }
#
# generated quantities {
#   real<lower=0,upper=1>theta=uniform_rng(0,1);
#   int<lower=0>S_sim=binomial_rng(N,theta);
# }

# %%
model_prior=pystan.StanModel('globe_prior.stan')
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_b771ecc8cd5c6cfc1b8f1c25158d6277 NOW.

# %%
R=1000
sim_uf=model_prior.sampling(data={'N':21},algorithm="Fixed_param", iter=R, warmup=0, chains=1, refresh=R,
                     seed=29042020)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-dda9a1fa7613> in <module>
#       3                      seed=29042020)
#       4
# ----> 5 sim_uf.head()
#
# AttributeError: 'stanfit4anon_model_b771ecc8cd5c6cfc1b8f1c25158d627' object has no attribute 'head'

# %%
params=sim_uf.extract()
theta=params['theta']
S_sim=params['S_sim']
fig, axes = plt.subplots(1, 2, figsize=(7, 4))

ax1=axes[0]
ax1.hist(theta,bins=20,color=dark,edgecolor=dark_highlight,density=True)
x=np.linspace(0,1,100)
ax1.plot(x,stats.uniform.pdf(x),color='black',linestyle='--')
ax1.set_xticks([0,1])
ax1.set_yticks([])
ax1.set_title(r'$\theta$')
ax1.annotate('Prior',xy=(0.25,1),xytext=(0.05,1.2),arrowprops={'arrowstyle':'->'})
ax2=axes[1]
ax2.hist(S_sim,color=dark,edgecolor=dark_highlight,density=True,bins=12)
ax2.set_xticks([0,11])
ax2.set_yticks([])
ax2.set_title('No. of successes')
plt.show()

# %% [markdown]
# ### Posterior parameter estimation and posterior predictive distribution

# %%
with open('globe_fit.stan', 'r') as file:
    print(file.read())
# Out:
# data {
#   int S; //number of successes
#   int N; //number of trials
# }
#
# parameters {
#   real <lower=0,upper=1> theta;
# }
#
# model {
#   theta ~ beta(1,1);//uniform prior
#   S ~ binomial(N,theta);
# }
# generated quantities {
#   int S_sim=0;
#   S_sim = binomial_rng(N,theta);
# }

# %%
model=pystan.StanModel('globe_fit.stan')
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_1f4d412bf50f8534ad8e06971689272e NOW.

# %%
data = dict(S = 7,
            N = 11)
fit = model.sampling(data=data, seed=26042020)

# %%
stan_utility.check_all_diagnostics(fit)
# Out:
# n_eff / iter looks reasonable for all parameters
# Rhat looks reasonable for all parameters
# 0.0 of 4000 iterations ended with a divergence (0.0%)
# 0 of 4000 iterations saturated the maximum tree depth of 10 (0.0%)
# E-BFMI indicated no pathological behavior

# %%
params=fit.extract()
theta=params['theta']
S_sim=params['S_sim']

# %%
fig, axes = plt.subplots(1, 2, figsize=(7, 4))
ax1=axes[0]
ax1.hist(theta,bins=20,color=dark,edgecolor=dark_highlight,density=True)
x=np.linspace(0,1,100)
ax1.plot(x,stats.uniform.pdf(x),color='black',linestyle='--')
ax1.set_xticks([0,1])
ax1.set_yticks([])
ax1.set_title(r'$\theta$')
ax1.annotate('Prior',xy=(0.25,1),xytext=(0.05,1.5),arrowprops={'arrowstyle':'->'})
ax2=axes[1]
ax2.hist(S_sim,color=dark,edgecolor=dark_highlight,density=True,bins=12)
ax2.set_xticks([0,11])
ax2.set_yticks([])
ax2.set_title('No. of successes')
plt.show()

# %%
np.median(theta)
# Out:
# 0.6215469651306377

# %%
az.hpd(theta,0.94)
# Out:
# array([0.38211383, 0.86758171])

# %% [markdown]
# ## Normal prior
# ### Prior predictive distribution

# %%
with open('globe_prior_normal.stan', 'r') as file:
    print(file.read())
# Out:
# data {
#   int N;
# }
#
# generated quantities {
#   real<lower=0,upper=1>theta=fabs(fmin(1,normal_rng(0.5,0.15)));
#   int<lower=0>S_sim=binomial_rng(N,theta);
# }

# %%
model_prior_normal=stan_utility.compile_model('globe_prior_normal.stan')
# Out:
# Using cached StanModel

# %%
R=1000
sim_nm=model_prior_normal.sampling(data={'N':11},algorithm="Fixed_param", iter=R, warmup=0, chains=1, refresh=R,
                     seed=29042020)

# %%
params=sim_nm.extract()
theta=params['theta']
S_sim=params['S_sim']
fig, axes = plt.subplots(1, 2, figsize=(7, 4))
ax1=axes[0]
ax1.hist(theta,bins=20,color=dark,edgecolor=dark_highlight,density=True)
x=np.linspace(0,1,100)
ax1.plot(x,stats.norm.pdf(x,0.5,0.15),color='black',linestyle='--')
ax1.set_xticks([0,1])
ax1.set_yticks([])
ax1.set_title(r'$\theta$')
ax1.annotate('Prior',xy=(0.25,stats.norm.pdf(0.25,0.5,0.15)),xytext=(0.05,1.5),arrowprops={'arrowstyle':'->'})
ax2=axes[1]
ax2.hist(S_sim,color=dark,edgecolor=dark_highlight,density=True,bins=12)
ax2.set_yticks([])
ax2.set_xticks([0,11])
ax2.set_title('No. of successes')
plt.show()

# %% [markdown]
# ### Posterior parameter estimation and posterior predictive distribution

# %%
with open('globe_fit_normal.stan', 'r') as file:
    print(file.read())
# Out:
# data {
#   int S; //number of successes
#   int N; //number of trials
# }
#
# parameters {
#   real <lower=0,upper=1> theta;
# }
#
# model {
#   theta ~ normal(0.5,0.15);
#   S ~ binomial(N,theta);
# }
# generated quantities {
#   int S_sim=0;
#   S_sim = binomial_rng(N,theta);
# }

# %%
model_normal=stan_utility.compile_model('globe_fit_normal.stan')
# Out:
# Using cached StanModel

# %%
data = dict(S = 7,
            N = 11)
fit_normal = model.sampling(data=data, seed=26042020)
stan_utility.check_all_diagnostics(fit_normal)
# Out:
# n_eff / iter looks reasonable for all parameters
# Rhat looks reasonable for all parameters
# 0.0 of 4000 iterations ended with a divergence (0.0%)
# 0 of 4000 iterations saturated the maximum tree depth of 10 (0.0%)
# E-BFMI indicated no pathological behavior

# %%
params=fit_normal.extract()
theta=params['theta']
S_sim=params['S_sim']

# %%
fig, axes = plt.subplots(1, 2, figsize=(7, 4))

ax1=axes[0]
ax1.hist(theta,bins=20,color=dark,edgecolor=dark_highlight,density=True)
x=np.linspace(0,1,100)
ax1.plot(x,stats.norm.pdf(x,0.5,0.15),color='black',linestyle='--')
ax1.set_xticks([0,1])
ax1.set_yticks([])
ax1.set_title(r'$\theta$')
ax1.annotate('Prior',xy=(0.25,stats.norm.pdf(0.25,0.5,0.15)),xytext=(0.05,1.5),arrowprops={'arrowstyle':'->'})
ax2=axes[1]
ax2.hist(S_sim,color=dark,edgecolor=dark_highlight,density=True,bins=12)
ax2.set_yticks([])
ax2.set_xticks([0,11])
ax2.set_title('No. of successes')
plt.show()

# %%
np.median(theta)
# Out:
# 0.6215469651306377

# %%
az.hpd(theta,0.94)
# Out:
# array([0.38211383, 0.86758171])
